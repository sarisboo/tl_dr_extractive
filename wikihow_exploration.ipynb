# %%
import numpy as np
import pandas as pd
import warnings
from cleaning_funcs import *
import re 
warnings.simplefilter(action='ignore')

# %%
# Consists of concatenation of all paragraphs as articles and bold lines as summaries
# wikihow_all = pd.read_csv('./datasets/wikihowAll.csv')

# %%
# wikihow_all.head()

# %%
# Consists of each paragraph and its summary
wikihow_sep = pd.read_csv('./datasets/wikihowSep.csv')

# %% [markdown]
# # Picking a Dataset
#
# ## Dataset structuring
#
# In a wikihow article a paragraph's summary usually comes at the top of the section and is highlighted in bold lines. We need to re-create the classic wikihow structure by appending the `headline` sentence back at the beginning of the paragraph for further processing.
#
# * We will create a column called `full_text` where the first line will be the sentence summarizing the whole paragraph.
#
# * The postion of the sentence at the beginning of the paragraph is not representative of a typical text/article structure (other than in a wikihow structure), so if we plan on using some kind of sentence location feature for the summarization it will probably end up not useful in our model just using the wikihow dataset. This problem could later be adressed by adding new and different summaries to the dataset.
#
# * The `wikihow_sep` dataset seems to be a good starting point for our analysis since it provides the paragraph and the sentence chosen to be its summary.

# %%
# Check the dataset decription
wikihow_sep.describe()
# Out:
#        overview         headline     text sectionLabel  \
# count   1583187          1585695  1387290      1583791
# unique   128543          1357301  1354189       188924
# top              \nFinished.\n\n      ;\n        Steps
# freq        826             4707    14164       449451
#
#                                                     title
# count                                             1585694
# unique                                             214613
# top     How to Create an Overall Status Workbook in XL...
# freq                                                  227

# %%
# Select preliminary useful columns 
wiki_filtered = wikihow_sep[['headline', 'text', 'title']]

# %%
wikihow_sep.head(30)
# Out:
#                                              overview  \
# 0    So you're a new or aspiring artist and your c...
# 1    If you want to be well-read, then, in the wor...
# 2    So you're a new or aspiring artist and your c...
# 3    So you're a new or aspiring artist and your c...
# 4    So you're a new or aspiring artist and your c...
# 5    So you're a new or aspiring artist and your c...
# 6    So you're a new or aspiring artist and your c...
# 7    So you're a new or aspiring artist and your c...
# 8    So you're a new or aspiring artist and your c...
# 9    So you're a new or aspiring artist and your c...
# 10   Stage names are used by all types of performe...
# 11   Burlesque in the U.S. is one of the few art f...
# 12   Burlesque in the U.S. is one of the few art f...
# 13   This article describes a general idea on how ...
# 14   Ticketmaster is a notorious and known website...
# 15   Your dream of becoming a famous artist may no...
# 16   According to the Bureau of Labor Statistics, ...
# 17   If you want to be well-read, then, in the wor...
# 18   If you want to be well-read, then, in the wor...
# 19   If you want to be well-read, then, in the wor...
# 20   If you want to be well-read, then, in the wor...
# 21   If you want to be well-read, then, in the wor...
# 22   If you want to be well-read, then, in the wor...
# 23   If you want to be well-read, then, in the wor...
# 24   If you want to be well-read, then, in the wor...
# 25   If you want to be well-read, then, in the wor...
# 26   Finding the nearest casino is challenging, es...
# 27   Stage names are used by all types of performe...
# 28   Stage names are used by all types of performe...
# 29   Stage names are used by all types of performe...
#
#                                              headline  \
# 0                              \nSell yourself first.
# 1                    \nRead the classics before 1600.
# 2                   \nJoin online artist communities.
# 3                             \nMake yourself public.
# 4                          \nBlog about your artwork.
# 5                            \nCreate a mailing list.
# 6                               \nTake good pictures.
# 7             \nBe sure to properly license your art.
# 8    \nConsider the option of creating your own site.
# 9   \nExpect this to be a gradual process and don'...
# 10     \nUnderstand what a stage name can do for you.
# 11           \nExamine your strengths as a performer.
# 12            \nWrite down what your weak points are.
# 13  \nPractice your material until you can perform...
# 14                   \nCreate a Ticketmaster account.
# 15                                        \nPractice.
# 16            \nTake a good look at your food budget.
# 17                \nRead the classics from 1600-1913.
# 18                \nRead the classics from 1914-1995.
# 19  \nRead more contemporary classics from 1980 to...
# 20                              \nRead short stories.
# 21                                      \nRead plays.
# 22                                     \nRead poetry.
# 23                                \nRead non-fiction.
# 24            \nRead popular fiction and non-fiction.
# 25                                       \nSet goals.
# 26                  \nListen to radio advertisements.
# 27        \nChoose a name that reflects your persona.
# 28                   \nHave a story behind your name.
# 29                     \nDo research about your name.
#
#                                                  text  \
# 0    Before doing anything else, stop and sum up y...
# 1    Reading the classics is the very first thing ...
# 2    Depending on what scale you intend to sell yo...
# 3    Get yourself out there as best as you can by ...
# 4    Given the hundreds of free blogging websites,...
# 5    This could be your most effective tool if man...
# 6    Like they say, "a picture's worth a thousand ...
# 7    Licensing art is a way of proving what belong...
# 8    Having your own site means that you can optim...
# 9    An online art business needs to be built up l...
# 10   A stage name can help you accomplish a number...
# 11   It's easy to spend hours focused on why you a...
# 12   Yep, time to be honest with yourself. If you ...
# 13                                                ;\n
# 14   This will enable you to do more than just rec...
# 15   Being called by the muse is a wonderful thing...
# 16   Restaurant eating accounted for the largest p...
# 17   Though a large amount of material is covered ...
# 18   This time period spans the advent of Modernis...
# 19   Though these books haven't stood the test of ...
# 20   Short stories are an incredible genre all the...
# 21   If you want to be well-read, then you also ha...
# 22   Though the people around you may be less like...
# 23   If you really want to be well-read, then you ...
# 24   If you really want to know what everyone is t...
# 25   How can setting goals make reading more fun, ...
# 26  \n\n\nListen to local radio broadcasts for adv...
# 27   Your stage name is a way to express yourself....
# 28   Whatever your stage name, people will likely ...
# 29   Look online and in name books to learn the me...
#
#                               sectionLabel  \
# 0                                    Steps
# 1                     Reading the Classics
# 2                                    Steps
# 3                                    Steps
# 4                                    Steps
# 5                                    Steps
# 6                                    Steps
# 7                                    Steps
# 8                                    Steps
# 9                                    Steps
# 10                   Choosing a Stage Name
# 11                                   Steps
# 12                                   Steps
# 13                                   Steps
# 14                                   Steps
# 15                    Building Your Skills
# 16                                   Steps
# 17                    Reading the Classics
# 18                    Reading the Classics
# 19                    Reading the Classics
# 20  Becoming Well-Read in Different Genres
# 21  Becoming Well-Read in Different Genres
# 22  Becoming Well-Read in Different Genres
# 23  Becoming Well-Read in Different Genres
# 24  Becoming Well-Read in Different Genres
# 25                 Making Reading More Fun
# 26                  Listening to the Radio
# 27                   Choosing a Stage Name
# 28                   Choosing a Stage Name
# 29                   Choosing a Stage Name
#
#                                                 title
# 0                         How to Sell Fine Art Online
# 1                                 How to Be Well Read
# 2                         How to Sell Fine Art Online
# 3                         How to Sell Fine Art Online
# 4                         How to Sell Fine Art Online
# 5                         How to Sell Fine Art Online
# 6                         How to Sell Fine Art Online
# 7                         How to Sell Fine Art Online
# 8                         How to Sell Fine Art Online
# 9                         How to Sell Fine Art Online
# 10                          How to Pick a Stage Name1
# 11                     How to Get More Burlesque Gigs
# 12                     How to Get More Burlesque Gigs
# 13  How to Get a Record Deal With Phantom City Studio
# 14                         How to Buy on Ticketmaster
# 15                      How to Become a Famous Artist
# 16               How to Reduce Entertainment Expenses
# 17                                How to Be Well Read
# 18                                How to Be Well Read
# 19                                How to Be Well Read
# 20                                How to Be Well Read
# 21                                How to Be Well Read
# 22                                How to Be Well Read
# 23                                How to Be Well Read
# 24                                How to Be Well Read
# 25                                How to Be Well Read
# 26                    How to Find the Nearest Casino1
# 27                          How to Pick a Stage Name1
# 28                          How to Pick a Stage Name1
# 29                          How to Pick a Stage Name1

# %%
wikihow_sep.iloc[0, 2]
# Out:
# " Before doing anything else, stop and sum up yourself as an artist. Now, think about how to translate that to an online profile. Be it the few words, Twitter allows you or an entire page of indulgence that your own website would allow you. Bring out the most salient features of your creativity, your experience, your passion, and your reasons for painting. Make it clear to readers why you are an artist who loves art, produces high quality art, and is a true champion of art. If you're not great with words, find a friend who can help you with this really important aspect of selling online – the establishment of your credibility and reliability.;\n"

# %%
# Re-create a full wikihow paragraph
wiki_filtered['full_text'] = wiki_filtered['headline'] + wiki_filtered['text']

# %%
#Reset index for later use
wiki_filtered = wiki_filtered.reset_index()

# %%
# Rename index column to text_id column 
wiki_filtered['text_id'] = wiki_filtered['index']

# %%
#Assign `text_id` by title 
wiki_filtered.title = pd.Categorical(wiki_filtered.title)

# %%
wiki_filtered['text_id'] = wiki_filtered.title.cat.codes

# %%
# Filter dataframe columns 
wiki_filtered = wiki_filtered[['text_id', 'full_text', 'title']]

# %%
#Explore end of dataframe
wiki_filtered.head(20)
# Out:
#     text_id                                          full_text  \
# 0    176320  \nSell yourself first. Before doing anything e...
# 1     12342  \nRead the classics before 1600. Reading the c...
# 2    176320  \nJoin online artist communities. Depending on...
# 3    176320  \nMake yourself public. Get yourself out there...
# 4    176320  \nBlog about your artwork. Given the hundreds ...
# 5    176320  \nCreate a mailing list. This could be your mo...
# 6    176320  \nTake good pictures. Like they say, "a pictur...
# 7    176320  \nBe sure to properly license your art. Licens...
# 8    176320  \nConsider the option of creating your own sit...
# 9    176320  \nExpect this to be a gradual process and don'...
# 10   152325  \nUnderstand what a stage name can do for you....
# 11    82580  \nExamine your strengths as a performer. It's ...
# 12    82580  \nWrite down what your weak points are. Yep, t...
# 13    89135  \nPractice your material until you can perform...
# 14    24209  \nCreate a Ticketmaster account. This will ena...
# 15    16342  \nPractice. Being called by the muse is a wond...
# 16   165814  \nTake a good look at your food budget. Restau...
# 17    12342  \nRead the classics from 1600-1913. Though a l...
# 18    12342  \nRead the classics from 1914-1995. This time ...
# 19    12342  \nRead more contemporary classics from 1980 to...
#
#                                                 title
# 0                         How to Sell Fine Art Online
# 1                                 How to Be Well Read
# 2                         How to Sell Fine Art Online
# 3                         How to Sell Fine Art Online
# 4                         How to Sell Fine Art Online
# 5                         How to Sell Fine Art Online
# 6                         How to Sell Fine Art Online
# 7                         How to Sell Fine Art Online
# 8                         How to Sell Fine Art Online
# 9                         How to Sell Fine Art Online
# 10                          How to Pick a Stage Name1
# 11                     How to Get More Burlesque Gigs
# 12                     How to Get More Burlesque Gigs
# 13  How to Get a Record Deal With Phantom City Studio
# 14                         How to Buy on Ticketmaster
# 15                      How to Become a Famous Artist
# 16               How to Reduce Entertainment Expenses
# 17                                How to Be Well Read
# 18                                How to Be Well Read
# 19                                How to Be Well Read

# %%
# Remove special characters
wiki_filtered['full_text'] = wiki_filtered['full_text'].apply(lambda x: clean_special_chars(str(x)))

# %%
#Remove digits
wiki_filtered['full_text'] = wiki_filtered['full_text'].apply(lambda x: remove_digits(str(x)))

# %%
# Deduplicates spaces
wiki_filtered['full_text'] = wiki_filtered['full_text'].apply(lambda x: dedupe_spaces(str(x)))

# %%
# Remove new lines
wiki_filtered['full_text'] = wiki_filtered['full_text'].apply(lambda x: remove_newlines(str(x)))

# %%
# Remove empty sentences
wiki_filtered['full_text'] = wiki_filtered['full_text'].apply(lambda x: remove_empty_sentences(str(x)))

# %%
wiki_filtered.head()
# Out:
#    text_id                                          full_text  \
# 0   176320   Sell yourself first. Before doing anything el...
# 1    12342   Read the classics before . Reading the classi...
# 2   176320   Join online artist communities. Depending on ...
# 3   176320   Make yourself public. Get yourself out there ...
# 4   176320   Blog about your artwork. Given the hundreds o...
#
#                          title
# 0  How to Sell Fine Art Online
# 1          How to Be Well Read
# 2  How to Sell Fine Art Online
# 3  How to Sell Fine Art Online
# 4  How to Sell Fine Art Online

# %%
# Create a list of tuples containing in index0, text_id and in index 1 the list of sentences corresponding to this text 
title_id_tup_set = list(set(list(zip(wiki_filtered['text_id'], wiki_filtered['title']))))

#Loop through the set to get dict
text_id_to_title = dict()
for element in title_id_tup_set:
    text_id_to_title[element[0]] = element[1]

# %%
text_id_to_title[176320]
# Out:
# 'How to Sell Fine Art Online'

# %%
# Split text by sentences   
wiki_filtered['sentences'] = wiki_filtered['full_text'].apply(lambda x: split_sentences(str(x)) )

# %%
# Create a list of tuples containing in index0, text_id and in index 1 the list of sentences corresponding to this text 
tuples = list(zip(wiki_filtered['text_id'], [sentence for sentence in wiki_filtered['sentences']]))

# %%
# Apply custom function to identify each sentence with its original text
tup_list = tup_list_maker(tuples)

# %%
# Converting the tuples list into a dataframe 
sentences = pd.DataFrame(tup_list, columns =['text_id', 'sentence'])

# %%
#Check the result
sentences.head()
# Out:
#    text_id                                           sentence
# 0   176320                                Sell yourself first
# 1   176320  Before doing anything else, stop and sum up yo...
# 2   176320  Now, think about how to translate that to an o...
# 3   176320  Be it the few words, Twitter allows you or an ...
# 4   176320  Bring out the most salient features of your cr...

# %%
sentences.tail()
# Out:
#          text_id                                           sentence
# 7354624    99172  Shade in color prints is typically made via va...
# 7354625    99172                                Look for blurriness
# 7354626    99172  Typically, fine details will be somewhat blurr...
# 7354627    99172  Often, the paper won t quite stick, or will ot...
# 7354628    99172  This is typically a sign of planographic litho...

# %%
sentences.head(30)
# Out:
#     text_id                                           sentence
# 0    176320                                Sell yourself first
# 1    176320  Before doing anything else, stop and sum up yo...
# 2    176320  Now, think about how to translate that to an o...
# 3    176320  Be it the few words, Twitter allows you or an ...
# 4    176320  Bring out the most salient features of your cr...
# 5    176320  Make it clear to readers why you are an artist...
# 6    176320  If you re not great with words, find a friend ...
# 7     12342                           Read the classics before
# 8     12342  Reading the classics is the very first thing y...
# 9     12342  If you want to build a solid foundation for yo...
# 10    12342  Remember that the novel didn t really get popu...
# 11    12342  Without reading the poetry of Homer or the pla...
# 12   176320                     Join online artist communities
# 13   176320  Depending on what scale you intend to sell you...
# 14   176320  With brokerage, you can also find many online ...
# 15   176320  There are also many other possible sites, such...
# 16   176320  Read the terms and conditions of every site ve...
# 17   176320  Know what commission or percentage the site ta...
# 18   176320  If your goal is to turn your art into an inves...
# 19   176320  This is largely because it is generally more d...
# 20   176320  It is best to see selling art online as an adj...
# 21   176320                               Make yourself public
# 22   176320  Get yourself out there as best as you can by a...
# 23   176320  Publish some example pieces around the web to ...
# 24   176320  Be sure to add a watermark to your digital ver...
# 25   176320  Spend a little time researching online the way...
# 26   176320               What works for them and what doesn t
# 27   176320  What do you like about their promotional strat...
# 28   176320  This type of research can give you a lot of id...
# 29   176320  Bookmark the sites of artists selling online t...

# %% [markdown]
# ## Adding a column specifying if the sentence is part of the summary
#
# To create our labeled dataset, for each sentence, we need to identify if they are part of the final summary or not. In order to do that, we will use a trick with pandas diff function on the `text_id` column which will compare subsequent rows and give us the difference, if this difference is other than 0, then the sentence was part of the summary.

# %%
# Strip leading and trailing whitespace
sentences['sentence'] = sentences['sentence'].apply(lambda sentence: sentence.strip())

# %%
# Take the headlines col put it in a set, clean and compare
headlines = wikihow_sep.headline
#Clean headlines
headlines
# Remove special characters
headlines = headlines.apply(lambda x: clean_special_chars(str(x)))
#Remove digits
headlines = headlines.apply(lambda x: remove_digits(str(x)))
#Remove sentence boundary
headlines = headlines.apply(lambda x: remove_boundaries(str(x)))
# Deduplicates spaces
headlines = headlines.apply(lambda x: dedupe_spaces(str(x)))
# Remove new lines
headlines = headlines.apply(lambda x: remove_newlines(str(x)))
# Remove empty sentences
headlines = headlines.apply(lambda x: remove_empty_sentences(str(x)))
#remove leading and trailing whitespace
headlines = headlines.apply(lambda sentence: sentence.strip())
#headline_set = set(headlines)
headline_array = np.array(headlines)

# %%
headline_array
# Out:
# array(['Sell yourself first', 'Read the classics before',
#        'Join online artist communities', ...,
#        'Look for the flatness of the ink',
#        'Look for the illusion of shade, created by multiple layers',
#        'Look for blurriness'], dtype=object)

# %%
sentences['is_summary'] = sentences.sentence.isin(headline_array).astype(int)

# %%
sentences.head(35)
# Out:
#     text_id                                           sentence  is_summary
# 0    176320                                Sell yourself first           1
# 1    176320  Before doing anything else, stop and sum up yo...           0
# 2    176320  Now, think about how to translate that to an o...           0
# 3    176320  Be it the few words, Twitter allows you or an ...           0
# 4    176320  Bring out the most salient features of your cr...           0
# 5    176320  Make it clear to readers why you are an artist...           0
# 6    176320  If you re not great with words, find a friend ...           0
# 7     12342                           Read the classics before           1
# 8     12342  Reading the classics is the very first thing y...           0
# 9     12342  If you want to build a solid foundation for yo...           0
# 10    12342  Remember that the novel didn t really get popu...           0
# 11    12342  Without reading the poetry of Homer or the pla...           0
# 12   176320                     Join online artist communities           1
# 13   176320  Depending on what scale you intend to sell you...           0
# 14   176320  With brokerage, you can also find many online ...           0
# 15   176320  There are also many other possible sites, such...           0
# 16   176320  Read the terms and conditions of every site ve...           0
# 17   176320  Know what commission or percentage the site ta...           0
# 18   176320  If your goal is to turn your art into an inves...           0
# 19   176320  This is largely because it is generally more d...           0
# 20   176320  It is best to see selling art online as an adj...           0
# 21   176320                               Make yourself public           1
# 22   176320  Get yourself out there as best as you can by a...           0
# 23   176320  Publish some example pieces around the web to ...           0
# 24   176320  Be sure to add a watermark to your digital ver...           0
# 25   176320  Spend a little time researching online the way...           0
# 26   176320               What works for them and what doesn t           0
# 27   176320  What do you like about their promotional strat...           0
# 28   176320  This type of research can give you a lot of id...           0
# 29   176320  Bookmark the sites of artists selling online t...           0
# 30   176320  Seize the power of Twitter and Facebook to inc...           0
# 31   176320  Tweet updates about your new paintings, your t...           0
# 32   176320  On Facebook, place photos of your artwork, dig...           0
# 33   176320                            Blog about your artwork           1
# 34   176320  Given the hundreds of free blogging websites, ...           0

# %%
sentences['is_summary'].value_counts()
# Out:
# 0    5911711
# 1    1442918
# Name: is_summary, dtype: int64

# %%
wikihow_sep.headline.describe()
# Out:
# count             1585695
# unique            1357301
# top       \nFinished.\n\n
# freq                 4707
# Name: headline, dtype: object

# %% [markdown]
# ## Split Sentences by Words
#
# Now that we have (mostly) cleaned our dataset, we need to analyse each sentence to later extract the features that we need for our analysis. To analyse our sentences, we need to split them into words and perform some frequency calculations on them.

# %%
# Strip leading and trailing whitespace
sentences['sentence'] = sentences['sentence'].apply(lambda sentence: sentence.strip())

# %%
# Strip leading and ending whitespace
sentences['words'] = sentences['sentence'].apply(lambda sentence: sentence.split(' '))

# %%
sentences.head(55)
# Out:
#     text_id                                           sentence  is_summary  \
# 0    176320                                Sell yourself first           1
# 1    176320  Before doing anything else, stop and sum up yo...           0
# 2    176320  Now, think about how to translate that to an o...           0
# 3    176320  Be it the few words, Twitter allows you or an ...           0
# 4    176320  Bring out the most salient features of your cr...           0
# 5    176320  Make it clear to readers why you are an artist...           0
# 6    176320  If you re not great with words, find a friend ...           0
# 7     12342                           Read the classics before           1
# 8     12342  Reading the classics is the very first thing y...           0
# 9     12342  If you want to build a solid foundation for yo...           0
# 10    12342  Remember that the novel didn t really get popu...           0
# 11    12342  Without reading the poetry of Homer or the pla...           0
# 12   176320                     Join online artist communities           1
# 13   176320  Depending on what scale you intend to sell you...           0
# 14   176320  With brokerage, you can also find many online ...           0
# 15   176320  There are also many other possible sites, such...           0
# 16   176320  Read the terms and conditions of every site ve...           0
# 17   176320  Know what commission or percentage the site ta...           0
# 18   176320  If your goal is to turn your art into an inves...           0
# 19   176320  This is largely because it is generally more d...           0
# 20   176320  It is best to see selling art online as an adj...           0
# 21   176320                               Make yourself public           1
# 22   176320  Get yourself out there as best as you can by a...           0
# 23   176320  Publish some example pieces around the web to ...           0
# 24   176320  Be sure to add a watermark to your digital ver...           0
# 25   176320  Spend a little time researching online the way...           0
# 26   176320               What works for them and what doesn t           0
# 27   176320  What do you like about their promotional strat...           0
# 28   176320  This type of research can give you a lot of id...           0
# 29   176320  Bookmark the sites of artists selling online t...           0
# 30   176320  Seize the power of Twitter and Facebook to inc...           0
# 31   176320  Tweet updates about your new paintings, your t...           0
# 32   176320  On Facebook, place photos of your artwork, dig...           0
# 33   176320                            Blog about your artwork           1
# 34   176320  Given the hundreds of free blogging websites, ...           0
# 35   176320  Most importantly, it s extremely useful to kee...           0
# 36   176320  A blog can pick up a lot of hits from search e...           0
# 37   176320  Be sure to name your blog something simple but...           0
# 38   176320  Read How to start a blog and How to increase w...           0
# 39   176320  A good way to test keywords for very little co...           0
# 40   176320  Play around with the words you use to title yo...           0
# 41   176320  Keep changing the words until you find the swe...           0
# 42   176320                              Create a mailing list           1
# 43   176320  This could be your most effective tool if mana...           0
# 44   176320  For every sale you make, every person who send...           0
# 45   176320  At designated intervals once a month, every ot...           0
# 46   176320  This keeps you on the radar of past customers,...           0
# 47   176320  And if it s a really wonderful newsletter, you...           0
# 48   176320  Every thoughtful mailing list includes an opt ...           0
# 49   176320  Don t be threatened by this see it as good hou...           0
# 50   176320  You re not online to hassle people who aren t ...           0
# 51   176320                                 Take good pictures           1
# 52   176320  Like they say, a picture s worth a thousand wo...           0
# 53   176320  Show detail, right down to paint strokes and p...           0
# 54   176320  Be willing to show potential buyers multiple s...           0
#
#                                                 words  \
# 0                             [Sell, yourself, first]
# 1   [Before, doing, anything, else,, stop, and, su...
# 2   [Now,, think, about, how, to, translate, that,...
# 3   [Be, it, the, few, words,, Twitter, allows, yo...
# 4   [Bring, out, the, most, salient, features, of,...
# 5   [Make, it, clear, to, readers, why, you, are, ...
# 6   [If, you, re, not, great, with, words,, find, ...
# 7                       [Read, the, classics, before]
# 8   [Reading, the, classics, is, the, very, first,...
# 9   [If, you, want, to, build, a, solid, foundatio...
# 10  [Remember, that, the, novel, didn, t, really, ...
# 11  [Without, reading, the, poetry, of, Homer, or,...
# 12                [Join, online, artist, communities]
# 13  [Depending, on, what, scale, you, intend, to, ...
# 14  [With, brokerage,, you, can, also, find, many,...
# 15  [There, are, also, many, other, possible, site...
# 16  [Read, the, terms, and, conditions, of, every,...
# 17  [Know, what, commission, or, percentage, the, ...
# 18  [If, your, goal, is, to, turn, your, art, into...
# 19  [This, is, largely, because, it, is, generally...
# 20  [It, is, best, to, see, selling, art, online, ...
# 21                           [Make, yourself, public]
# 22  [Get, yourself, out, there, as, best, as, you,...
# 23  [Publish, some, example, pieces, around, the, ...
# 24  [Be, sure, to, add, a, watermark, to, your, di...
# 25  [Spend, a, little, time, researching, online, ...
# 26      [What, works, for, them, and, what, doesn, t]
# 27  [What, do, you, like, about, their, promotiona...
# 28  [This, type, of, research, can, give, you, a, ...
# 29  [Bookmark, the, sites, of, artists, selling, o...
# 30  [Seize, the, power, of, Twitter, and, Facebook...
# 31  [Tweet, updates, about, your, new, paintings,,...
# 32  [On, Facebook,, place, photos, of, your, artwo...
# 33                       [Blog, about, your, artwork]
# 34  [Given, the, hundreds, of, free, blogging, web...
# 35  [Most, importantly,, it, s, extremely, useful,...
# 36  [A, blog, can, pick, up, a, lot, of, hits, fro...
# 37  [Be, sure, to, name, your, blog, something, si...
# 38  [Read, How, to, start, a, blog, and, How, to, ...
# 39  [A, good, way, to, test, keywords, for, very, ...
# 40  [Play, around, with, the, words, you, use, to,...
# 41  [Keep, changing, the, words, until, you, find,...
# 42                         [Create, a, mailing, list]
# 43  [This, could, be, your, most, effective, tool,...
# 44  [For, every, sale, you, make,, every, person, ...
# 45  [At, designated, intervals, once, a, month,, e...
# 46  [This, keeps, you, on, the, radar, of, past, c...
# 47  [And, if, it, s, a, really, wonderful, newslet...
# 48  [Every, thoughtful, mailing, list, includes, a...
# 49  [Don, t, be, threatened, by, this, see, it, as...
# 50  [You, re, not, online, to, hassle, people, who...
# 51                             [Take, good, pictures]
# 52  [Like, they, say,, a, picture, s, worth, a, th...
# 53  [Show, detail,, right, down, to, paint, stroke...
# 54  [Be, willing, to, show, potential, buyers, mul...
#
#                           title
# 0   How to Sell Fine Art Online
# 1   How to Sell Fine Art Online
# 2   How to Sell Fine Art Online
# 3   How to Sell Fine Art Online
# 4   How to Sell Fine Art Online
# 5   How to Sell Fine Art Online
# 6   How to Sell Fine Art Online
# 7           How to Be Well Read
# 8           How to Be Well Read
# 9           How to Be Well Read
# 10          How to Be Well Read
# 11          How to Be Well Read
# 12  How to Sell Fine Art Online
# 13  How to Sell Fine Art Online
# 14  How to Sell Fine Art Online
# 15  How to Sell Fine Art Online
# 16  How to Sell Fine Art Online
# 17  How to Sell Fine Art Online
# 18  How to Sell Fine Art Online
# 19  How to Sell Fine Art Online
# 20  How to Sell Fine Art Online
# 21  How to Sell Fine Art Online
# 22  How to Sell Fine Art Online
# 23  How to Sell Fine Art Online
# 24  How to Sell Fine Art Online
# 25  How to Sell Fine Art Online
# 26  How to Sell Fine Art Online
# 27  How to Sell Fine Art Online
# 28  How to Sell Fine Art Online
# 29  How to Sell Fine Art Online
# 30  How to Sell Fine Art Online
# 31  How to Sell Fine Art Online
# 32  How to Sell Fine Art Online
# 33  How to Sell Fine Art Online
# 34  How to Sell Fine Art Online
# 35  How to Sell Fine Art Online
# 36  How to Sell Fine Art Online
# 37  How to Sell Fine Art Online
# 38  How to Sell Fine Art Online
# 39  How to Sell Fine Art Online
# 40  How to Sell Fine Art Online
# 41  How to Sell Fine Art Online
# 42  How to Sell Fine Art Online
# 43  How to Sell Fine Art Online
# 44  How to Sell Fine Art Online
# 45  How to Sell Fine Art Online
# 46  How to Sell Fine Art Online
# 47  How to Sell Fine Art Online
# 48  How to Sell Fine Art Online
# 49  How to Sell Fine Art Online
# 50  How to Sell Fine Art Online
# 51  How to Sell Fine Art Online
# 52  How to Sell Fine Art Online
# 53  How to Sell Fine Art Online
# 54  How to Sell Fine Art Online

# %%
wikihow_sep['title'].head()
# Out:
# 0    How to Sell Fine Art Online
# 1            How to Be Well Read
# 2    How to Sell Fine Art Online
# 3    How to Sell Fine Art Online
# 4    How to Sell Fine Art Online
# Name: title, dtype: object

# %%
sentences['title'] = sentences['text_id'].map(text_id_to_title)

# %%
sentences.head(20)
# Out:
#     text_id                                           sentence  is_summary  \
# 0    176320                                Sell yourself first           1
# 1    176320  Before doing anything else, stop and sum up yo...           0
# 2    176320  Now, think about how to translate that to an o...           0
# 3    176320  Be it the few words, Twitter allows you or an ...           0
# 4    176320  Bring out the most salient features of your cr...           0
# 5    176320  Make it clear to readers why you are an artist...           0
# 6    176320  If you re not great with words, find a friend ...           0
# 7     12342                           Read the classics before           1
# 8     12342  Reading the classics is the very first thing y...           0
# 9     12342  If you want to build a solid foundation for yo...           0
# 10    12342  Remember that the novel didn t really get popu...           0
# 11    12342  Without reading the poetry of Homer or the pla...           0
# 12   176320                     Join online artist communities           1
# 13   176320  Depending on what scale you intend to sell you...           0
# 14   176320  With brokerage, you can also find many online ...           0
# 15   176320  There are also many other possible sites, such...           0
# 16   176320  Read the terms and conditions of every site ve...           0
# 17   176320  Know what commission or percentage the site ta...           0
# 18   176320  If your goal is to turn your art into an inves...           0
# 19   176320  This is largely because it is generally more d...           0
#
#                                                 words  \
# 0                             [Sell, yourself, first]
# 1   [Before, doing, anything, else,, stop, and, su...
# 2   [Now,, think, about, how, to, translate, that,...
# 3   [Be, it, the, few, words,, Twitter, allows, yo...
# 4   [Bring, out, the, most, salient, features, of,...
# 5   [Make, it, clear, to, readers, why, you, are, ...
# 6   [If, you, re, not, great, with, words,, find, ...
# 7                       [Read, the, classics, before]
# 8   [Reading, the, classics, is, the, very, first,...
# 9   [If, you, want, to, build, a, solid, foundatio...
# 10  [Remember, that, the, novel, didn, t, really, ...
# 11  [Without, reading, the, poetry, of, Homer, or,...
# 12                [Join, online, artist, communities]
# 13  [Depending, on, what, scale, you, intend, to, ...
# 14  [With, brokerage,, you, can, also, find, many,...
# 15  [There, are, also, many, other, possible, site...
# 16  [Read, the, terms, and, conditions, of, every,...
# 17  [Know, what, commission, or, percentage, the, ...
# 18  [If, your, goal, is, to, turn, your, art, into...
# 19  [This, is, largely, because, it, is, generally...
#
#                           title
# 0   How to Sell Fine Art Online
# 1   How to Sell Fine Art Online
# 2   How to Sell Fine Art Online
# 3   How to Sell Fine Art Online
# 4   How to Sell Fine Art Online
# 5   How to Sell Fine Art Online
# 6   How to Sell Fine Art Online
# 7           How to Be Well Read
# 8           How to Be Well Read
# 9           How to Be Well Read
# 10          How to Be Well Read
# 11          How to Be Well Read
# 12  How to Sell Fine Art Online
# 13  How to Sell Fine Art Online
# 14  How to Sell Fine Art Online
# 15  How to Sell Fine Art Online
# 16  How to Sell Fine Art Online
# 17  How to Sell Fine Art Online
# 18  How to Sell Fine Art Online
# 19  How to Sell Fine Art Online

# %%
cleaned_sentences = sentences

# %%
len(cleaned_sentences)
# Out:
# 7354629

# %%
# Length of the sentence 
cleaned_sentences['sentence_len'] = cleaned_sentences['sentence'].apply(lambda x: len(str(x).split(' ')))

# %%
cleaned_sentences.head()
# Out:
#    text_id                                           sentence  is_summary  \
# 0   176320                                Sell yourself first           1
# 1   176320  Before doing anything else, stop and sum up yo...           0
# 2   176320  Now, think about how to translate that to an o...           0
# 3   176320  Be it the few words, Twitter allows you or an ...           0
# 4   176320  Bring out the most salient features of your cr...           0
#
#                                                words  \
# 0                            [Sell, yourself, first]
# 1  [Before, doing, anything, else,, stop, and, su...
# 2  [Now,, think, about, how, to, translate, that,...
# 3  [Be, it, the, few, words,, Twitter, allows, yo...
# 4  [Bring, out, the, most, salient, features, of,...
#
#                          title  sentence_len
# 0  How to Sell Fine Art Online             3
# 1  How to Sell Fine Art Online            12
# 2  How to Sell Fine Art Online            11
# 3  How to Sell Fine Art Online            21
# 4  How to Sell Fine Art Online            18

# %%
indexNames = cleaned_sentences[(cleaned_sentences['sentence_len'] == 1) & (cleaned_sentences['is_summary'] != 'yes')].index
indexNames
# Out:
# Int64Index([     70,      71,      72,     110,     142,     144,     145,
#                 150,     157,     167,
#             ...
#             7353299, 7353307, 7353671, 7353696, 7353729, 7353822, 7353948,
#             7354045, 7354456, 7354458],
#            dtype='int64', length=105506)

# %%
# Delete these row indexes from dataFrame
cleaned_sentences.drop(indexNames, inplace= True)

# %%
cleaned_sentences[cleaned_sentences['sentence'] == '2']
# Out:
# Empty DataFrame
# Columns: [text_id, sentence, is_summary, words, title, sentence_len]
# Index: []

# %%
#Removing nonesense titles 
num_title_indexes = cleaned_sentences[(cleaned_sentences['sentence'].str.contains('[0-9]', regex=True)) & (cleaned_sentences['sentence_len'] == 1)].index

# %%
num_title_indexes
# Out:
# Int64Index([], dtype='int64')

# %%
# Delete these row indexes from dataFrame
cleaned_sentences.drop(num_title_indexes, inplace= True)

# %%
empty_indexes = cleaned_sentences[cleaned_sentences['sentence'] == ''].index
empty_indexes
# Out:
# Int64Index([], dtype='int64')

# %%
cleaned_sentences.drop(empty_indexes, inplace= True)

# %%
cleaned_sentences.head(55)
# Out:
#     text_id                                           sentence  is_summary  \
# 0    176320                                Sell yourself first           1
# 1    176320  Before doing anything else, stop and sum up yo...           0
# 2    176320  Now, think about how to translate that to an o...           0
# 3    176320  Be it the few words, Twitter allows you or an ...           0
# 4    176320  Bring out the most salient features of your cr...           0
# 5    176320  Make it clear to readers why you are an artist...           0
# 6    176320  If you re not great with words, find a friend ...           0
# 7     12342                           Read the classics before           1
# 8     12342  Reading the classics is the very first thing y...           0
# 9     12342  If you want to build a solid foundation for yo...           0
# 10    12342  Remember that the novel didn t really get popu...           0
# 11    12342  Without reading the poetry of Homer or the pla...           0
# 12   176320                     Join online artist communities           1
# 13   176320  Depending on what scale you intend to sell you...           0
# 14   176320  With brokerage, you can also find many online ...           0
# 15   176320  There are also many other possible sites, such...           0
# 16   176320  Read the terms and conditions of every site ve...           0
# 17   176320  Know what commission or percentage the site ta...           0
# 18   176320  If your goal is to turn your art into an inves...           0
# 19   176320  This is largely because it is generally more d...           0
# 20   176320  It is best to see selling art online as an adj...           0
# 21   176320                               Make yourself public           1
# 22   176320  Get yourself out there as best as you can by a...           0
# 23   176320  Publish some example pieces around the web to ...           0
# 24   176320  Be sure to add a watermark to your digital ver...           0
# 25   176320  Spend a little time researching online the way...           0
# 26   176320               What works for them and what doesn t           0
# 27   176320  What do you like about their promotional strat...           0
# 28   176320  This type of research can give you a lot of id...           0
# 29   176320  Bookmark the sites of artists selling online t...           0
# 30   176320  Seize the power of Twitter and Facebook to inc...           0
# 31   176320  Tweet updates about your new paintings, your t...           0
# 32   176320  On Facebook, place photos of your artwork, dig...           0
# 33   176320                            Blog about your artwork           1
# 34   176320  Given the hundreds of free blogging websites, ...           0
# 35   176320  Most importantly, it s extremely useful to kee...           0
# 36   176320  A blog can pick up a lot of hits from search e...           0
# 37   176320  Be sure to name your blog something simple but...           0
# 38   176320  Read How to start a blog and How to increase w...           0
# 39   176320  A good way to test keywords for very little co...           0
# 40   176320  Play around with the words you use to title yo...           0
# 41   176320  Keep changing the words until you find the swe...           0
# 42   176320                              Create a mailing list           1
# 43   176320  This could be your most effective tool if mana...           0
# 44   176320  For every sale you make, every person who send...           0
# 45   176320  At designated intervals once a month, every ot...           0
# 46   176320  This keeps you on the radar of past customers,...           0
# 47   176320  And if it s a really wonderful newsletter, you...           0
# 48   176320  Every thoughtful mailing list includes an opt ...           0
# 49   176320  Don t be threatened by this see it as good hou...           0
# 50   176320  You re not online to hassle people who aren t ...           0
# 51   176320                                 Take good pictures           1
# 52   176320  Like they say, a picture s worth a thousand wo...           0
# 53   176320  Show detail, right down to paint strokes and p...           0
# 54   176320  Be willing to show potential buyers multiple s...           0
#
#                                                 words  \
# 0                             [Sell, yourself, first]
# 1   [Before, doing, anything, else,, stop, and, su...
# 2   [Now,, think, about, how, to, translate, that,...
# 3   [Be, it, the, few, words,, Twitter, allows, yo...
# 4   [Bring, out, the, most, salient, features, of,...
# 5   [Make, it, clear, to, readers, why, you, are, ...
# 6   [If, you, re, not, great, with, words,, find, ...
# 7                       [Read, the, classics, before]
# 8   [Reading, the, classics, is, the, very, first,...
# 9   [If, you, want, to, build, a, solid, foundatio...
# 10  [Remember, that, the, novel, didn, t, really, ...
# 11  [Without, reading, the, poetry, of, Homer, or,...
# 12                [Join, online, artist, communities]
# 13  [Depending, on, what, scale, you, intend, to, ...
# 14  [With, brokerage,, you, can, also, find, many,...
# 15  [There, are, also, many, other, possible, site...
# 16  [Read, the, terms, and, conditions, of, every,...
# 17  [Know, what, commission, or, percentage, the, ...
# 18  [If, your, goal, is, to, turn, your, art, into...
# 19  [This, is, largely, because, it, is, generally...
# 20  [It, is, best, to, see, selling, art, online, ...
# 21                           [Make, yourself, public]
# 22  [Get, yourself, out, there, as, best, as, you,...
# 23  [Publish, some, example, pieces, around, the, ...
# 24  [Be, sure, to, add, a, watermark, to, your, di...
# 25  [Spend, a, little, time, researching, online, ...
# 26      [What, works, for, them, and, what, doesn, t]
# 27  [What, do, you, like, about, their, promotiona...
# 28  [This, type, of, research, can, give, you, a, ...
# 29  [Bookmark, the, sites, of, artists, selling, o...
# 30  [Seize, the, power, of, Twitter, and, Facebook...
# 31  [Tweet, updates, about, your, new, paintings,,...
# 32  [On, Facebook,, place, photos, of, your, artwo...
# 33                       [Blog, about, your, artwork]
# 34  [Given, the, hundreds, of, free, blogging, web...
# 35  [Most, importantly,, it, s, extremely, useful,...
# 36  [A, blog, can, pick, up, a, lot, of, hits, fro...
# 37  [Be, sure, to, name, your, blog, something, si...
# 38  [Read, How, to, start, a, blog, and, How, to, ...
# 39  [A, good, way, to, test, keywords, for, very, ...
# 40  [Play, around, with, the, words, you, use, to,...
# 41  [Keep, changing, the, words, until, you, find,...
# 42                         [Create, a, mailing, list]
# 43  [This, could, be, your, most, effective, tool,...
# 44  [For, every, sale, you, make,, every, person, ...
# 45  [At, designated, intervals, once, a, month,, e...
# 46  [This, keeps, you, on, the, radar, of, past, c...
# 47  [And, if, it, s, a, really, wonderful, newslet...
# 48  [Every, thoughtful, mailing, list, includes, a...
# 49  [Don, t, be, threatened, by, this, see, it, as...
# 50  [You, re, not, online, to, hassle, people, who...
# 51                             [Take, good, pictures]
# 52  [Like, they, say,, a, picture, s, worth, a, th...
# 53  [Show, detail,, right, down, to, paint, stroke...
# 54  [Be, willing, to, show, potential, buyers, mul...
#
#                           title  sentence_len
# 0   How to Sell Fine Art Online             3
# 1   How to Sell Fine Art Online            12
# 2   How to Sell Fine Art Online            11
# 3   How to Sell Fine Art Online            21
# 4   How to Sell Fine Art Online            18
# 5   How to Sell Fine Art Online            24
# 6   How to Sell Fine Art Online            29
# 7           How to Be Well Read             4
# 8           How to Be Well Read            16
# 9           How to Be Well Read            33
# 10          How to Be Well Read            22
# 11          How to Be Well Read            21
# 12  How to Sell Fine Art Online             4
# 13  How to Sell Fine Art Online            28
# 14  How to Sell Fine Art Online            35
# 15  How to Sell Fine Art Online            58
# 16  How to Sell Fine Art Online            10
# 17  How to Sell Fine Art Online            45
# 18  How to Sell Fine Art Online            26
# 19  How to Sell Fine Art Online            36
# 20  How to Sell Fine Art Online            22
# 21  How to Sell Fine Art Online             3
# 22  How to Sell Fine Art Online            12
# 23  How to Sell Fine Art Online            18
# 24  How to Sell Fine Art Online            17
# 25  How to Sell Fine Art Online            15
# 26  How to Sell Fine Art Online             8
# 27  How to Sell Fine Art Online            15
# 28  How to Sell Fine Art Online            29
# 29  How to Sell Fine Art Online            28
# 30  How to Sell Fine Art Online            14
# 31  How to Sell Fine Art Online            17
# 32  How to Sell Fine Art Online            30
# 33  How to Sell Fine Art Online             4
# 34  How to Sell Fine Art Online            17
# 35  How to Sell Fine Art Online            34
# 36  How to Sell Fine Art Online            24
# 37  How to Sell Fine Art Online            22
# 38  How to Sell Fine Art Online            16
# 39  How to Sell Fine Art Online            16
# 40  How to Sell Fine Art Online            24
# 41  How to Sell Fine Art Online            20
# 42  How to Sell Fine Art Online             4
# 43  How to Sell Fine Art Online            10
# 44  How to Sell Fine Art Online            29
# 45  How to Sell Fine Art Online            45
# 46  How to Sell Fine Art Online            12
# 47  How to Sell Fine Art Online            32
# 48  How to Sell Fine Art Online             9
# 49  How to Sell Fine Art Online            24
# 50  How to Sell Fine Art Online            11
# 51  How to Sell Fine Art Online             3
# 52  How to Sell Fine Art Online            22
# 53  How to Sell Fine Art Online            10
# 54  How to Sell Fine Art Online            19

# %%
#Saving the cleaned Dataset
cleaned_sentences.to_csv('./datasets/clean_wikihow_sep.csv', index=False)
